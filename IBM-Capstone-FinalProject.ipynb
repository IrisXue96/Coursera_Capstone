# %%
# !conda install -c conda-forge beautifulsoup4 --yes

# !conda install -c conda-forge geopy --yes

# !conda install -c conda-forge folium=0.5.0 --yes
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\xueya\anaconda3
#
#   added / updated specs:
#     - beautifulsoup4
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     beautifulsoup4-4.9.1       |   py37hc8dfbb8_0         164 KB  conda-forge
#     ca-certificates-2020.6.20  |       hecda079_0         184 KB  conda-forge
#     certifi-2020.6.20          |   py37hc8dfbb8_0         151 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         498 KB
#
# The following packages will be UPDATED:
#
#   beautifulsoup4     pkgs/main::beautifulsoup4-4.9.0-py37_0 --> conda-forge::beautifulsoup4-4.9.1-py37hc8dfbb8_0
#   ca-certificates                     2020.4.5.1-hecc5488_0 --> 2020.6.20-hecda079_0
#   certifi                         2020.4.5.1-py37hc8dfbb8_0 --> 2020.6.20-py37hc8dfbb8_0
#
#
#
# Downloading and Extracting Packages
#
# certifi-2020.6.20    | 151 KB    |            |   0%
# certifi-2020.6.20    | 151 KB    | #          |  11%
# certifi-2020.6.20    | 151 KB    | ########## | 100%
#
# ca-certificates-2020 | 184 KB    |            |   0%
# ca-certificates-2020 | 184 KB    | ########## | 100%
#
# beautifulsoup4-4.9.1 | 164 KB    |            |   0%
# beautifulsoup4-4.9.1 | 164 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\xueya\anaconda3
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-2.0.0                |     pyh9f0ad1d_0          63 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          63 KB
#
# The following packages will be UPDATED:
#
#   geopy                                 1.22.0-pyh9f0ad1d_0 --> 2.0.0-pyh9f0ad1d_0
#
#
#
# Downloading and Extracting Packages
#
# geopy-2.0.0          | 63 KB     |            |   0%
# geopy-2.0.0          | 63 KB     | ##5        |  25%
# geopy-2.0.0          | 63 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\xueya\anaconda3
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         713 KB
#
# The following NEW packages will be INSTALLED:
#
#   altair             conda-forge/noarch::altair-4.1.0-py_1
#   branca             conda-forge/noarch::branca-0.4.1-py_0
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#
#
#
# Downloading and Extracting Packages
#
# branca-0.4.1         | 26 KB     |            |   0%
# branca-0.4.1         | 26 KB     | ######1    |  62%
# branca-0.4.1         | 26 KB     | ########## | 100%
#
# vincent-0.4.4        | 28 KB     |            |   0%
# vincent-0.4.4        | 28 KB     | #####7     |  58%
# vincent-0.4.4        | 28 KB     | ########## | 100%
#
# altair-4.1.0         | 614 KB    |            |   0%
# altair-4.1.0         | 614 KB    | #5         |  16%
# altair-4.1.0         | 614 KB    | #######5   |  76%
# altair-4.1.0         | 614 KB    | ########## | 100%
#
# folium-0.5.0         | 45 KB     |            |   0%
# folium-0.5.0         | 45 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
import json
from bs4 import BeautifulSoup
import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans


import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %% [markdown]
# # Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'PPSZ11ZZJZYTZKIXOABEQYW1H1WZTWVTXUEVKJ5ULONUP1DQ' # your Foursquare ID
CLIENT_SECRET = '1TKOQ425RCFWYEWRYMLUYJRKYQ0POCVXSVBYDK5DAOUE4TJ4' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: PPSZ11ZZJZYTZKIXOABEQYW1H1WZTWVTXUEVKJ5ULONUP1DQ
# CLIENT_SECRET:1TKOQ425RCFWYEWRYMLUYJRKYQ0POCVXSVBYDK5DAOUE4TJ4

# %% [markdown]
# ## Assume our destination for the trip is the Universal Studios Florida.

# %%
address = '6000 Universal Blvd, Orlando, FL'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 28.471878949999997 -81.47121064527349

# %% [markdown]
# ## Search for the hotels that are within 1.5km from the park.

# %%
search_query = 'Hotel'
radius = 1500
print(search_query + ' .... OK!')
# Out:
# Hotel .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=PPSZ11ZZJZYTZKIXOABEQYW1H1WZTWVTXUEVKJ5ULONUP1DQ&client_secret=1TKOQ425RCFWYEWRYMLUYJRKYQ0POCVXSVBYDK5DAOUE4TJ4&ll=28.471878949999997,-81.47121064527349&v=20180604&query=Hotel&radius=1500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5efac16b2f5bc4555bca3781'},
#  'response': {'venues': [{'id': '4283ee00f964a52097221fe3',
#     'name': 'Hard Rock Hotel at Universal Orlando',
#     'location': {'address': '5800 Universal Blvd',
#      'lat': 28.47714156614553,
#      'lng': -81.464524269104,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.47714156614553,
#        'lng': -81.464524269104}],
#      'distance': 878,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['5800 Universal Blvd',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d12f951735',
#       'name': 'Resort',
#       'pluralName': 'Resorts',
#       'shortName': 'Resort',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/resort_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1725601',
#      'url': 'https://www.grubhub.com/restaurant/the-kitchen-at-hard-rock-hotel-5800-universal-boulevard-orlando/1725601?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1725601',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '4b05868cf964a5206c6522e3',
#     'name': 'Loews Portofino Bay Hotel at Universal Orlando',
#     'location': {'address': '5601 Universal Blvd',
#      'lat': 28.480845917714237,
#      'lng': -81.46084348802358,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.480845917714237,
#        'lng': -81.46084348802358}],
#      'distance': 1423,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['5601 Universal Blvd',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '61572298'},
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '4bcf5b4b0ffdce726465b2c0',
#     'name': 'Orlando Continental Plaza Hotel',
#     'location': {'address': '6825 Visitors Cir',
#      'lat': 28.462913039141355,
#      'lng': -81.46629583379527,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.462913039141355,
#        'lng': -81.46629583379527},
#       {'label': 'entrance', 'lat': 28.46297, 'lng': -81.466548}],
#      'distance': 1107,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['6825 Visitors Cir',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '42014063'},
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '5c51bf4da35dce002c7008ab',
#     'name': 'Aventura Hotel Pool',
#     'location': {'address': '6725 Adventure Way',
#      'lat': 28.465333636858904,
#      'lng': -81.47141218185425,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.465333636858904,
#        'lng': -81.47141218185425}],
#      'distance': 728,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['6725 Adventure Way',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132951735',
#       'name': 'Hotel Pool',
#       'pluralName': 'Hotel Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '4d41abb34acd236a9632fca9',
#     'name': 'Hard Rock Hotel Beach Pool',
#     'location': {'address': '5800 Universal Blvd',
#      'lat': 28.476547710217396,
#      'lng': -81.4647989246974,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.476547710217396,
#        'lng': -81.4647989246974},
#       {'label': 'entrance', 'lat': 28.477074, 'lng': -81.465359}],
#      'distance': 814,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['5800 Universal Blvd',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132951735',
#       'name': 'Hotel Pool',
#       'pluralName': 'Hotel Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '4c2881b697d00f4767e23fea',
#     'name': 'Hard Rock Hotel Shuttle Bus',
#     'location': {'crossStreet': 'Abbey Road\u200b',
#      'lat': 28.477907865989437,
#      'lng': -81.46257481758214,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.477907865989437,
#        'lng': -81.46257481758214}],
#      'distance': 1079,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Orlando, FL 32819', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fe931735',
#       'name': 'Bus Station',
#       'pluralName': 'Bus Stations',
#       'shortName': 'Bus Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '4ba93dbcf964a5205a173ae3',
#     'name': 'Best Western Orlando Gateway Hotel',
#     'location': {'address': '7299 Universal Blvd',
#      'lat': 28.4581031,
#      'lng': -81.4634998,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.4581031,
#        'lng': -81.4634998}],
#      'distance': 1709,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['7299 Universal Blvd',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '37625794'},
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '5b6c7e89b54618002c271d2e',
#     'name': "Universal's Aventura Hotel",
#     'location': {'address': '6725 Adventure Way',
#      'lat': 28.46507579036141,
#      'lng': -81.47118790667739,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.46507579036141,
#        'lng': -81.47118790667739}],
#      'distance': 757,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['6725 Adventure Way',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '4bf860375ec320a135af88d3',
#     'name': 'DoubleTree Hotel Pool',
#     'location': {'address': '5780 Major Blvd',
#      'lat': 28.479177565900443,
#      'lng': -81.45702417937746,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.479177565900443,
#        'lng': -81.45702417937746}],
#      'distance': 1608,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['5780 Major Blvd',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132951735',
#       'name': 'Hotel Pool',
#       'pluralName': 'Hotel Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '521b89f611d2570f28e1bf39',
#     'name': 'Hard Rock Hotel Valet',
#     'location': {'lat': 28.47372246281708,
#      'lng': -81.46717069065397,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.47372246281708,
#        'lng': -81.46717069065397}],
#      'distance': 445,
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Orlando, FL', 'United States']},
#     'categories': [{'id': '4f04b1572fb6e1c99f3db0bf',
#       'name': 'Storage Facility',
#       'pluralName': 'Storage Facilities',
#       'shortName': 'Storage',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/storage_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '5101eb56e4b01fa7d7592c15',
#     'name': 'Pricilla Hotel',
#     'location': {'address': 'Universal Studios',
#      'crossStreet': 'New York',
#      'lat': 28.476559393850568,
#      'lng': -81.46938004248699,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.476559393850568,
#        'lng': -81.46938004248699}],
#      'distance': 550,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Universal Studios (New York)',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '4f573e99e4b0f52af66fac72',
#     'name': 'Hard Rock Hotel Gym',
#     'location': {'lat': 28.47680713598119,
#      'lng': -81.4642470605936,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.47680713598119,
#        'lng': -81.4642470605936}],
#      'distance': 874,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Orlando, FL 32819', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '4dab210e93a04642f08e96ad',
#     'name': 'Beachclub at Hard Rock Hotel',
#     'location': {'address': '5800 Universal Blvd',
#      'lat': 28.476491151414063,
#      'lng': -81.4650403025143,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.476491151414063,
#        'lng': -81.4650403025143}],
#      'distance': 792,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['5800 Universal Blvd',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '4df511ea22718759f8254ceb',
#     'name': 'Priscilla Hotel For Single Young Ladies',
#     'location': {'address': 'park',
#      'lat': 28.47645278,
#      'lng': -81.46927171,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.47645278,
#        'lng': -81.46927171}],
#      'distance': 543,
#      'cc': 'US',
#      'city': 'universal studios',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['park', 'universal studios, FL', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '4e0884fad4c03ae0b9d02f97',
#     'name': 'Butterfly Garden at Hard Rock Hotel',
#     'location': {'address': '5800 Universal Blvd',
#      'lat': 28.47689905527237,
#      'lng': -81.46346225713904,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.47689905527237,
#        'lng': -81.46346225713904}],
#      'distance': 941,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['5800 Universal Blvd',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d15a941735',
#       'name': 'Garden',
#       'pluralName': 'Gardens',
#       'shortName': 'Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '5101ed5be4b04647cde45bf2',
#     'name': 'Empire Hotel',
#     'location': {'address': 'Universal Studios',
#      'lat': 28.477204393467634,
#      'lng': -81.46917090757952,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.477204393467634,
#        'lng': -81.46917090757952}],
#      'distance': 625,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Universal Studios',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '4d3dd07614aa8cfa862ab75e',
#     'name': 'Hard Rock Hotel Engineering Shop',
#     'location': {'address': '5800 Universal Blvd',
#      'lat': 28.47672845300759,
#      'lng': -81.46552435982025,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.47672845300759,
#        'lng': -81.46552435982025}],
#      'distance': 775,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['5800 Universal Blvd',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '5bfac19d1c0b34002ca05fa5',
#     'name': 'Lowes Adventura Hotel At Universal Studios',
#     'location': {'address': '6725 Adventure Way',
#      'lat': 28.465465545654297,
#      'lng': -81.47111511230469,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.465465545654297,
#        'lng': -81.47111511230469}],
#      'distance': 713,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['6725 Adventure Way',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '4d0817a24adb370401e6fa54',
#     'name': 'Club 7 at the Hard Rock Hotel',
#     'location': {'lat': 28.477155093132765,
#      'lng': -81.46436110732672,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.477155093132765,
#        'lng': -81.46436110732672}],
#      'distance': 891,
#      'cc': 'US',
#      'state': 'Florida',
#      'country': 'United States',
#      'formattedAddress': ['Florida', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '5380969a498e15919e8b3748',
#     'name': 'Hollywood Hotel',
#     'location': {'address': '6301 Vine St.',
#      'crossStreet': 'Hollywood Blvd.',
#      'lat': 28.482650756835938,
#      'lng': -81.46574401855469,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.482650756835938,
#        'lng': -81.46574401855469}],
#      'distance': 1313,
#      'postalCode': '32811',
#      'cc': 'US',
#      'city': 'Universal City',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['6301 Vine St. (Hollywood Blvd.)',
#       'Universal City, FL 32811',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '4e3b433b62e19d610951e6bc',
#     'name': 'The Lord Hotel',
#     'location': {'address': '5859 American Way',
#      'lat': 28.464859008789062,
#      'lng': -81.46050262451172,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.464859008789062,
#        'lng': -81.46050262451172}],
#      'distance': 1307,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['5859 American Way',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '4bc361dbdce4eee1ac93719d',
#     'name': 'The Blue Palm Hotel',
#     'location': {'address': '5859 American Way',
#      'lat': 28.464859008789062,
#      'lng': -81.46050262451172,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 28.464809,
#        'lng': -81.4603},
#       {'label': 'display',
#        'lat': 28.464859008789062,
#        'lng': -81.46050262451172}],
#      'distance': 1307,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['5859 American Way',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '4b058690f964a5200f6622e3',
#     'name': 'Hard Rock Cafe Orlando',
#     'location': {'address': '6050 Universal Blvd',
#      'crossStreet': 'at Universal CityWalk',
#      'lat': 28.4737377306628,
#      'lng': -81.46756102331352,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.4737377306628,
#        'lng': -81.46756102331352}],
#      'distance': 412,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['6050 Universal Blvd (at Universal CityWalk)',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '56aa371be4b08b9a8d573538',
#       'name': 'Theme Restaurant',
#       'pluralName': 'Theme Restaurants',
#       'shortName': 'Theme Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '504ca24de4b072019695b9ab',
#     'name': 'My Favorite Hotel',
#     'location': {'lat': 28.46320928699819,
#      'lng': -81.46191517694697,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.46320928699819,
#        'lng': -81.46191517694697}],
#      'distance': 1326,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Orlando, FL 32819', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f1931735',
#       'name': 'General Entertainment',
#       'pluralName': 'General Entertainment',
#       'shortName': 'Entertainment',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '4d2460aa53e4a0937dbb8677',
#     'name': 'Loewe Hotel',
#     'location': {'lat': 28.46786511718431,
#      'lng': -81.4581073828309,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.46786511718431,
#        'lng': -81.4581073828309}],
#      'distance': 1357,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Orlando, FL 32819', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '4e6f7b77483bd41a3dc90b4e',
#     'name': 'Crown Royal Hotel',
#     'location': {'lat': 28.461679367391778,
#      'lng': -81.46170602139841,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.461679367391778,
#        'lng': -81.46170602139841}],
#      'distance': 1467,
#      'cc': 'US',
#      'state': 'Florida',
#      'country': 'United States',
#      'formattedAddress': ['Florida', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '4b4b9717f964a52036a126e3',
#     'name': 'Loews Royal Pacific Resort',
#     'location': {'address': '6300 Hollywood Way',
#      'lat': 28.46863856649586,
#      'lng': -81.46750317005582,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.46863856649586,
#        'lng': -81.46750317005582}],
#      'distance': 511,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['6300 Hollywood Way',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '61577394'},
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '532993de498efd18cd04522d',
#     'name': 'Galaxy Bowl',
#     'location': {'address': '6550 Adventure Way',
#      'lat': 28.465626123749512,
#      'lng': -81.47345614724958,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.465626123749512,
#        'lng': -81.47345614724958}],
#      'distance': 729,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['6550 Adventure Way',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e4931735',
#       'name': 'Bowling Alley',
#       'pluralName': 'Bowling Alleys',
#       'shortName': 'Bowling Alley',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/bowling_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '4b4c0456f964a5200fad26e3',
#     'name': 'Hard Rock Live Orlando',
#     'location': {'address': '6050 Universal Blvd',
#      'crossStreet': 'at Universal CityWalk',
#      'lat': 28.473423010350565,
#      'lng': -81.4673390817503,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.473423010350565,
#        'lng': -81.4673390817503}],
#      'distance': 416,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['6050 Universal Blvd (at Universal CityWalk)',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e5931735',
#       'name': 'Music Venue',
#       'pluralName': 'Music Venues',
#       'shortName': 'Music Venue',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593492173',
#     'hasPerk': False},
#    {'id': '4bb9489098c7ef3b6cff3102',
#     'name': 'Holiday Inn & Suites Across From Universal Orlando',
#     'location': {'address': '5905 S Kirkman Rd',
#      'crossStreet': 'at Major Blvd',
#      'lat': 28.476468,
#      'lng': -81.457653,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.476468,
#        'lng': -81.457653}],
#      'distance': 1421,
#      'postalCode': '32819',
#      'cc': 'US',
#      'city': 'Orlando',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['5905 S Kirkman Rd (at Major Blvd)',
#       'Orlando, FL 32819',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593492173',
#     'hasPerk': False}]}}

# %% [markdown]
# ## transform into pandas dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.sort_values(by=['location.distance'], ascending = True, inplace=True)
dataframe.head()
# Out:
# C:\Users\xueya\anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                           id                                     name  \
# 22  4b058690f964a5200f6622e3                   Hard Rock Cafe Orlando
# 28  4b4c0456f964a5200fad26e3                   Hard Rock Live Orlando
# 9   521b89f611d2570f28e1bf39                    Hard Rock Hotel Valet
# 26  4b4b9717f964a52036a126e3               Loews Royal Pacific Resort
# 13  4df511ea22718759f8254ceb  Priscilla Hotel For Single Young Ladies
#
#                                            categories    referralId  hasPerk  \
# 22  [{'id': '56aa371be4b08b9a8d573538', 'name': 'T...  v-1593492173    False
# 28  [{'id': '4bf58dd8d48988d1e5931735', 'name': 'M...  v-1593492173    False
# 9   [{'id': '4f04b1572fb6e1c99f3db0bf', 'name': 'S...  v-1593492173    False
# 26  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1593492173    False
# 13  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...  v-1593492173    False
#
#        location.address  location.lat  location.lng  \
# 22  6050 Universal Blvd     28.473738    -81.467561
# 28  6050 Universal Blvd     28.473423    -81.467339
# 9                   NaN     28.473722    -81.467171
# 26   6300 Hollywood Way     28.468639    -81.467503
# 13                 park     28.476453    -81.469272
#
#                               location.labeledLatLngs  location.distance  ...  \
# 22  [{'label': 'display', 'lat': 28.4737377306628,...                412  ...
# 28  [{'label': 'display', 'lat': 28.47342301035056...                416  ...
# 9   [{'label': 'display', 'lat': 28.47372246281708...                445  ...
# 26  [{'label': 'display', 'lat': 28.46863856649586...                511  ...
# 13  [{'label': 'display', 'lat': 28.47645278, 'lng...                543  ...
#
#    location.country                          location.formattedAddress  \
# 22    United States  [6050 Universal Blvd (at Universal CityWalk), ...
# 28    United States  [6050 Universal Blvd (at Universal CityWalk), ...
# 9     United States                       [Orlando, FL, United States]
# 26    United States  [6300 Hollywood Way, Orlando, FL 32819, United...
# 13    United States       [park, universal studios, FL, United States]
#
#    delivery.id delivery.url delivery.provider.name  \
# 22         NaN          NaN                    NaN
# 28         NaN          NaN                    NaN
# 9          NaN          NaN                    NaN
# 26         NaN          NaN                    NaN
# 13         NaN          NaN                    NaN
#
#    delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 22                           NaN                          NaN
# 28                           NaN                          NaN
# 9                            NaN                          NaN
# 26                           NaN                          NaN
# 13                           NaN                          NaN
#
#    delivery.provider.icon.name venuePage.id   location.crossStreet
# 22                         NaN          NaN  at Universal CityWalk
# 28                         NaN          NaN  at Universal CityWalk
# 9                          NaN          NaN                    NaN
# 26                         NaN     61577394                    NaN
# 13                         NaN          NaN                    NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ### keep only useful information.

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)
# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]
dataframe_filtered= dataframe_filtered.loc[dataframe_filtered['categories'] == "Hotel"]
dataframe_filtered
# Out:
#                                                  name categories  \
# 26                         Loews Royal Pacific Resort      Hotel
# 10                                     Pricilla Hotel      Hotel
# 15                                       Empire Hotel      Hotel
# 17         Lowes Adventura Hotel At Universal Studios      Hotel
# 7                          Universal's Aventura Hotel      Hotel
# 18                      Club 7 at the Hard Rock Hotel      Hotel
# 2                     Orlando Continental Plaza Hotel      Hotel
# 20                                     The Lord Hotel      Hotel
# 21                                The Blue Palm Hotel      Hotel
# 24                                        Loewe Hotel      Hotel
# 29  Holiday Inn & Suites Across From Universal Orl...      Hotel
# 1      Loews Portofino Bay Hotel at Universal Orlando      Hotel
# 6                  Best Western Orlando Gateway Hotel      Hotel
#
#                 address        lat        lng  \
# 26   6300 Hollywood Way  28.468639 -81.467503
# 10    Universal Studios  28.476559 -81.469380
# 15    Universal Studios  28.477204 -81.469171
# 17   6725 Adventure Way  28.465466 -81.471115
# 7    6725 Adventure Way  28.465076 -81.471188
# 18                  NaN  28.477155 -81.464361
# 2     6825 Visitors Cir  28.462913 -81.466296
# 20    5859 American Way  28.464859 -81.460503
# 21    5859 American Way  28.464859 -81.460503
# 24                  NaN  28.467865 -81.458107
# 29    5905 S Kirkman Rd  28.476468 -81.457653
# 1   5601 Universal Blvd  28.480846 -81.460843
# 6   7299 Universal Blvd  28.458103 -81.463500
#
#                                        labeledLatLngs  distance postalCode  \
# 26  [{'label': 'display', 'lat': 28.46863856649586...       511      32819
# 10  [{'label': 'display', 'lat': 28.47655939385056...       550      32819
# 15  [{'label': 'display', 'lat': 28.47720439346763...       625      32819
# 17  [{'label': 'display', 'lat': 28.46546554565429...       713      32819
# 7   [{'label': 'display', 'lat': 28.46507579036141...       757      32819
# 18  [{'label': 'display', 'lat': 28.47715509313276...       891        NaN
# 2   [{'label': 'display', 'lat': 28.46291303914135...      1107      32819
# 20  [{'label': 'display', 'lat': 28.46485900878906...      1307      32819
# 21  [{'label': 'entrance', 'lat': 28.464809, 'lng'...      1307      32819
# 24  [{'label': 'display', 'lat': 28.46786511718431...      1357      32819
# 29  [{'label': 'display', 'lat': 28.476468, 'lng':...      1421      32819
# 1   [{'label': 'display', 'lat': 28.48084591771423...      1423      32819
# 6   [{'label': 'display', 'lat': 28.4581031, 'lng'...      1709      32819
#
#     cc     city    state        country  \
# 26  US  Orlando       FL  United States
# 10  US  Orlando       FL  United States
# 15  US  Orlando       FL  United States
# 17  US  Orlando       FL  United States
# 7   US  Orlando       FL  United States
# 18  US      NaN  Florida  United States
# 2   US  Orlando       FL  United States
# 20  US  Orlando       FL  United States
# 21  US  Orlando       FL  United States
# 24  US  Orlando       FL  United States
# 29  US  Orlando       FL  United States
# 1   US  Orlando       FL  United States
# 6   US  Orlando       FL  United States
#
#                                      formattedAddress    crossStreet  \
# 26  [6300 Hollywood Way, Orlando, FL 32819, United...            NaN
# 10  [Universal Studios (New York), Orlando, FL 328...       New York
# 15  [Universal Studios, Orlando, FL 32819, United ...            NaN
# 17  [6725 Adventure Way, Orlando, FL 32819, United...            NaN
# 7   [6725 Adventure Way, Orlando, FL 32819, United...            NaN
# 18                           [Florida, United States]            NaN
# 2   [6825 Visitors Cir, Orlando, FL 32819, United ...            NaN
# 20  [5859 American Way, Orlando, FL 32819, United ...            NaN
# 21  [5859 American Way, Orlando, FL 32819, United ...            NaN
# 24                 [Orlando, FL 32819, United States]            NaN
# 29  [5905 S Kirkman Rd (at Major Blvd), Orlando, F...  at Major Blvd
# 1   [5601 Universal Blvd, Orlando, FL 32819, Unite...            NaN
# 6   [7299 Universal Blvd, Orlando, FL 32819, Unite...            NaN
#
#                           id
# 26  4b4b9717f964a52036a126e3
# 10  5101eb56e4b01fa7d7592c15
# 15  5101ed5be4b04647cde45bf2
# 17  5bfac19d1c0b34002ca05fa5
# 7   5b6c7e89b54618002c271d2e
# 18  4d0817a24adb370401e6fa54
# 2   4bcf5b4b0ffdce726465b2c0
# 20  4e3b433b62e19d610951e6bc
# 21  4bc361dbdce4eee1ac93719d
# 24  4d2460aa53e4a0937dbb8677
# 29  4bb9489098c7ef3b6cff3102
# 1   4b05868cf964a5206c6522e3
# 6   4ba93dbcf964a5205a173ae3

# %% [markdown]
# ## visualize hotels that are nearby

# %%
dataframe_filtered.name
# Out:
# 26                           Loews Royal Pacific Resort
# 10                                       Pricilla Hotel
# 15                                         Empire Hotel
# 17           Lowes Adventura Hotel At Universal Studios
# 7                            Universal's Aventura Hotel
# 18                        Club 7 at the Hard Rock Hotel
# 2                       Orlando Continental Plaza Hotel
# 20                                       The Lord Hotel
# 21                                  The Blue Palm Hotel
# 24                                          Loewe Hotel
# 29    Holiday Inn & Suites Across From Universal Orl...
# 1        Loews Portofino Bay Hotel at Universal Orlando
# 6                    Best Western Orlando Gateway Hotel
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Compare the rating of the nearest 13 hotels

# %%
#1st
venue_id = '4b4b9717f964a52036a126e3' # ID of Loews Royal Pacific Resort#
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 8.8

# %%
id_list = [dataframe_filtered.id]
id_list
# Out:
# [26    4b4b9717f964a52036a126e3
#  10    5101eb56e4b01fa7d7592c15
#  15    5101ed5be4b04647cde45bf2
#  17    5bfac19d1c0b34002ca05fa5
#  7     5b6c7e89b54618002c271d2e
#  18    4d0817a24adb370401e6fa54
#  2     4bcf5b4b0ffdce726465b2c0
#  20    4e3b433b62e19d610951e6bc
#  21    4bc361dbdce4eee1ac93719d
#  24    4d2460aa53e4a0937dbb8677
#  29    4bb9489098c7ef3b6cff3102
#  1     4b05868cf964a5206c6522e3
#  6     4ba93dbcf964a5205a173ae3
#  Name: id, dtype: object]

# %%
#2nd 
venue_id = '5101eb56e4b01fa7d7592c15' 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
#3rd
venue_id = '5101ed5be4b04647cde45bf2' 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
#4
venue_id = '5bfac19d1c0b34002ca05fa5' 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
#5
venue_id = '5b6c7e89b54618002c271d2e' 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 8.1

# %%
#6
venue_id = '4d0817a24adb370401e6fa54' 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.9

# %%
#7
venue_id = '4bcf5b4b0ffdce726465b2c0' 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 5.2

# %%
#8
venue_id = '4e3b433b62e19d610951e6bc' 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
#9
venue_id = '4bc361dbdce4eee1ac93719d' 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
#10
venue_id = '4d2460aa53e4a0937dbb8677' 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
#11
venue_id = '4bb9489098c7ef3b6cff3102' 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.9

# %%
#12
venue_id = '4b05868cf964a5206c6522e3' 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 9.2

# %%
#13
venue_id = '4ba93dbcf964a5205a173ae3' 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.6

# %%
distance_list = [dataframe_filtered.distance]
distance_list
# Out:
# [26     511
#  10     550
#  15     625
#  17     713
#  7      757
#  18     891
#  2     1107
#  20    1307
#  21    1307
#  24    1357
#  29    1421
#  1     1423
#  6     1709
#  Name: distance, dtype: int64]

# %% [markdown]
# ## Search restaurants around the three top rated hotels

# %%
#1 Loews Royal Pacific Resort
latitude = 28.468639
longitude = -81.467503
search_query = 'restaurant'
radius = 1000
print(search_query + ' .... OK!')
# Out:
# restaurant .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
results_1 = requests.get(url).json()
venues_1 = results_1['response']['venues']

# tranform venues into a dataframe
restaurant1 = json_normalize(venues_1)
restaurant1.sort_values(by=['location.distance'], ascending = True, inplace=True)
restaurant1.head()
# Out:
# C:\Users\xueya\anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                           id                               name  \
# 10  539ce2dd498e40a9f6829815               Vivo Italian Kitchen
# 7   4beded76e24d20a144417214   Bob Marley: A Tribute To Freedom
# 9   4baa623af964a52008653ae3  Circus McGurkus Cafe Stoo-pendous
# 13  4b5c7d95f964a520783229e3              Thunder Falls Terrace
# 14  4b50c562f964a520b83127e3                             Mythos
#
#                                            categories    referralId  hasPerk  \
# 10  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1593501978    False
# 7   [{'id': '4bf58dd8d48988d144941735', 'name': 'C...  v-1593501978    False
# 9   [{'id': '4bf58dd8d48988d147941735', 'name': 'D...  v-1593501978    False
# 13  [{'id': '4bf58dd8d48988d1df931735', 'name': 'B...  v-1593501978    False
# 14  [{'id': '4bf58dd8d48988d10e941735', 'name': 'G...  v-1593501978    False
#
#        location.address  location.lat  location.lng  \
# 10  6000 Universal Blvd     28.473063    -81.465647
# 7   6000 Universal Blvd     28.472875    -81.465123
# 9         Seuss Landing     28.473163    -81.469803
# 13        Jurassic Park     28.469765    -81.473314
# 14   The Lost Continent     28.472640    -81.471439
#
#                               location.labeledLatLngs  location.distance  ...  \
# 10  [{'label': 'display', 'lat': 28.47306265781803...                524  ...
# 7   [{'label': 'display', 'lat': 28.47287499588204...                525  ...
# 9   [{'label': 'display', 'lat': 28.47316347107087...                551  ...
# 13  [{'label': 'display', 'lat': 28.46976489750437...                582  ...
# 14  [{'label': 'display', 'lat': 28.47264026289861...                588  ...
#
#    location.country                          location.formattedAddress  \
# 10    United States  [6000 Universal Blvd (at Universal CityWalk), ...
# 7     United States  [6000 Universal Blvd (at Universal Citywalk), ...
# 9     United States  [Seuss Landing (at Islands of Adventure), Orla...
# 13    United States  [Jurassic Park (Islands of Adventure), Orlando...
# 14    United States  [The Lost Continent (at Islands of Adventure),...
#
#        location.crossStreet delivery.id delivery.url delivery.provider.name  \
# 10    at Universal CityWalk         NaN          NaN                    NaN
# 7     at Universal Citywalk         NaN          NaN                    NaN
# 9   at Islands of Adventure         NaN          NaN                    NaN
# 13     Islands of Adventure         NaN          NaN                    NaN
# 14  at Islands of Adventure         NaN          NaN                    NaN
#
#    delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 10                           NaN                          NaN
# 7                            NaN                          NaN
# 9                            NaN                          NaN
# 13                           NaN                          NaN
# 14                           NaN                          NaN
#
#    delivery.provider.icon.name venuePage.id
# 10                         NaN          NaN
# 7                          NaN          NaN
# 9                          NaN          NaN
# 13                         NaN          NaN
# 14                         NaN          NaN
#
# [5 rows x 24 columns]

# %%
filtered_columns1 = ['name', 'categories'] + [col for col in restaurant1.columns if col.startswith('location.')] + ['id']
restaurant1_filtered = restaurant1.loc[:, filtered_columns1]
# filter the category for each row
restaurant1_filtered['categories'] = restaurant1_filtered.apply(get_category_type, axis=1)
# clean column names by keeping only last term
restaurant1_filtered.columns = [column.split('.')[-1] for column in restaurant1_filtered.columns]
restaurant1_filtered.shape
# Out:
# (15, 15)

# %%
restaurant1_filtered
# Out:
#                                  name            categories  \
# 10               Vivo Italian Kitchen    Italian Restaurant
# 7    Bob Marley: A Tribute To Freedom  Caribbean Restaurant
# 9   Circus McGurkus Cafe Stoo-pendous                 Diner
# 13              Thunder Falls Terrace             BBQ Joint
# 14                             Mythos      Greek Restaurant
# 8                    Oshio Korean BBQ     Korean Restaurant
# 4               Las Brisas Restaurant                  Food
# 0     Via Brasil Brazilian Restaurant  Brazilian Restaurant
# 5              Kohola Reef Restaurant             BBQ Joint
# 11              Tavistock Restaurants              Building
# 1          Louie's Italian Restaurant    Italian Restaurant
# 12                   The Palm Orlando            Steakhouse
# 2                Thai Silk Restaurant       Thai Restaurant
# 6                    Tabla Restaurant     Indian Restaurant
# 3                 La Palma Restaurant    Mexican Restaurant
#
#                    address        lat        lng  \
# 10     6000 Universal Blvd  28.473063 -81.465647
# 7      6000 Universal Blvd  28.472875 -81.465123
# 9            Seuss Landing  28.473163 -81.469803
# 13           Jurassic Park  28.469765 -81.473314
# 14      The Lost Continent  28.472640 -81.471439
# 8        6800 Visitors Cir  28.463251 -81.465498
# 4    6233 International Dr  28.462166 -81.467087
# 0    6315 International Dr  28.461344 -81.467443
# 5             Wave Village  28.462716 -81.472433
# 11     7680 Universal Blvd  28.461786 -81.463047
# 1                 New York  28.477348 -81.469196
# 12     5800 Universal Blvd  28.477117 -81.464620
# 2        6803 S Kirkman Rd  28.463811 -81.457950
# 6   5847 Grand National Dr  28.472176 -81.455630
# 3    5545 International Dr  28.463289 -81.455559
#
#                                        labeledLatLngs  distance postalCode  \
# 10  [{'label': 'display', 'lat': 28.47306265781803...       524      32819
# 7   [{'label': 'display', 'lat': 28.47287499588204...       525      32819
# 9   [{'label': 'display', 'lat': 28.47316347107087...       551      32819
# 13  [{'label': 'display', 'lat': 28.46976489750437...       582      32819
# 14  [{'label': 'display', 'lat': 28.47264026289861...       588      32819
# 8   [{'label': 'display', 'lat': 28.46325100820970...       631      32819
# 4   [{'label': 'entrance', 'lat': 28.461708, 'lng'...       721      32819
# 0   [{'label': 'display', 'lat': 28.46134391842936...       812      32819
# 5   [{'label': 'display', 'lat': 28.46271588727033...       816      32819
# 11  [{'label': 'display', 'lat': 28.46178633363962...       878      32819
# 1   [{'label': 'display', 'lat': 28.47734786754995...       983      32819
# 12  [{'label': 'display', 'lat': 28.47711656455560...       984      32819
# 2   [{'label': 'display', 'lat': 28.46381058901147...      1078      32819
# 6   [{'label': 'display', 'lat': 28.4721764, 'lng'...      1226      32819
# 3   [{'label': 'display', 'lat': 28.46328926086425...      1311      32819
#
#     cc     city state        country  \
# 10  US  Orlando    FL  United States
# 7   US  Orlando    FL  United States
# 9   US  Orlando    FL  United States
# 13  US  Orlando    FL  United States
# 14  US  Orlando    FL  United States
# 8   US  Orlando    FL  United States
# 4   US  Orlando    FL  United States
# 0   US  Orlando    FL  United States
# 5   US  Orlando    FL  United States
# 11  US  Orlando    FL  United States
# 1   US  Orlando    FL  United States
# 12  US  Orlando    FL  United States
# 2   US  Orlando    FL  United States
# 6   US  Orlando    FL  United States
# 3   US  Orlando    FL  United States
#
#                                      formattedAddress  \
# 10  [6000 Universal Blvd (at Universal CityWalk), ...
# 7   [6000 Universal Blvd (at Universal Citywalk), ...
# 9   [Seuss Landing (at Islands of Adventure), Orla...
# 13  [Jurassic Park (Islands of Adventure), Orlando...
# 14  [The Lost Continent (at Islands of Adventure),...
# 8   [6800 Visitors Cir, Orlando, FL 32819, United ...
# 4   [6233 International Dr, Orlando, FL 32819, Uni...
# 0   [6315 International Dr, Orlando, FL 32819, Uni...
# 5   [Wave Village (Universal's Volcano Bay), Orlan...
# 11  [7680 Universal Blvd, Orlando, FL 32819, Unite...
# 1   [New York (Universal Studios Florida), Orlando...
# 12  [5800 Universal Blvd, Orlando, FL 32819, Unite...
# 2   [6803 S Kirkman Rd (entrance on Grand National...
# 6   [5847 Grand National Dr (Kirkman Road), Orland...
# 3   [5545 International Dr, Orlando, FL 32819, Uni...
#
#                          crossStreet                        id
# 10             at Universal CityWalk  539ce2dd498e40a9f6829815
# 7              at Universal Citywalk  4beded76e24d20a144417214
# 9            at Islands of Adventure  4baa623af964a52008653ae3
# 13              Islands of Adventure  4b5c7d95f964a520783229e3
# 14           at Islands of Adventure  4b50c562f964a520b83127e3
# 8                                NaN  54e02fbb498e4bfeb5320730
# 4                                NaN  4f327fbb19836c91c7ddbf07
# 0                                NaN  58b1ada219b1ad54934d5229
# 5            Universal's Volcano Bay  5900dbfb67e5f22787d2e7be
# 11                               NaN  4e147ff1ae60fe00dfdf9326
# 1          Universal Studios Florida  4bfe9064f7c82d7f0dc18f04
# 12                               NaN  4b058697f964a520256722e3
# 2   entrance on Grand National Drive  4ba02534f964a520755d37e3
# 6                       Kirkman Road  4b058699f964a5206a6722e3
# 3                                NaN  4dd53f0eae60a78cec68e542

# %%
#2 Universal 
latitude = 28.465076
longitude = -81.471188
search_query = 'restaurant'
radius = 1000
print(search_query + ' .... OK!')
# Out:
# restaurant .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
results_2 = requests.get(url).json()
venues_2 = results_2['response']['venues']

# tranform venues into a dataframe
restaurant2 = json_normalize(venues_2)
restaurant2.sort_values(by=['location.distance'], ascending = True, inplace=True)
restaurant2.head()
# Out:
# C:\Users\xueya\anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                           id                             name  \
# 4   5900dbfb67e5f22787d2e7be           Kohola Reef Restaurant
# 5   4f327fbb19836c91c7ddbf07            Las Brisas Restaurant
# 0   58b1ada219b1ad54934d5229  Via Brasil Brazilian Restaurant
# 12  4b5c7d95f964a520783229e3            Thunder Falls Terrace
# 9   54e02fbb498e4bfeb5320730                 Oshio Korean BBQ
#
#                                            categories    referralId  hasPerk  \
# 4   [{'id': '4bf58dd8d48988d1df931735', 'name': 'B...  v-1593502306    False
# 5   [{'id': '4d4b7105d754a06374d81259', 'name': 'F...  v-1593502306    False
# 0   [{'id': '4bf58dd8d48988d16b941735', 'name': 'B...  v-1593502306    False
# 12  [{'id': '4bf58dd8d48988d1df931735', 'name': 'B...  v-1593502306    False
# 9   [{'id': '4bf58dd8d48988d113941735', 'name': 'K...  v-1593502306    False
#
#          location.address  location.lat  location.lng  \
# 4            Wave Village     28.462716    -81.472433
# 5   6233 International Dr     28.462166    -81.467087
# 0   6315 International Dr     28.461344    -81.467443
# 12          Jurassic Park     28.469765    -81.473314
# 9       6800 Visitors Cir     28.463251    -81.465498
#
#                               location.labeledLatLngs  location.distance  ...  \
# 4   [{'label': 'display', 'lat': 28.46271588727033...                289  ...
# 5   [{'label': 'entrance', 'lat': 28.461708, 'lng'...                515  ...
# 0   [{'label': 'display', 'lat': 28.46134391842936...                554  ...
# 12  [{'label': 'display', 'lat': 28.46976489750437...                561  ...
# 9   [{'label': 'display', 'lat': 28.46325100820970...                592  ...
#
#    location.country                          location.formattedAddress  \
# 4     United States  [Wave Village (Universal's Volcano Bay), Orlan...
# 5     United States  [6233 International Dr, Orlando, FL 32819, Uni...
# 0     United States  [6315 International Dr, Orlando, FL 32819, Uni...
# 12    United States  [Jurassic Park (Islands of Adventure), Orlando...
# 9     United States  [6800 Visitors Cir, Orlando, FL 32819, United ...
#
#    delivery.id delivery.url delivery.provider.name  \
# 4          NaN          NaN                    NaN
# 5          NaN          NaN                    NaN
# 0          NaN          NaN                    NaN
# 12         NaN          NaN                    NaN
# 9          NaN          NaN                    NaN
#
#    delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 4                            NaN                          NaN
# 5                            NaN                          NaN
# 0                            NaN                          NaN
# 12                           NaN                          NaN
# 9                            NaN                          NaN
#
#    delivery.provider.icon.name venuePage.id     location.crossStreet
# 4                          NaN          NaN  Universal's Volcano Bay
# 5                          NaN          NaN                      NaN
# 0                          NaN          NaN                      NaN
# 12                         NaN          NaN     Islands of Adventure
# 9                          NaN    477065924                      NaN
#
# [5 rows x 24 columns]

# %%
filtered_columns2 = ['name', 'categories'] + [col for col in restaurant2.columns if col.startswith('location.')] + ['id']
restaurant2_filtered = restaurant2.loc[:, filtered_columns2]
# filter the category for each row
restaurant2_filtered['categories'] = restaurant2_filtered.apply(get_category_type, axis=1)
# clean column names by keeping only last term
restaurant2_filtered.columns = [column.split('.')[-1] for column in restaurant2_filtered.columns]
restaurant2_filtered.shape
# Out:
# (16, 15)

# %%
restaurant2_filtered
# Out:
#                                  name                 categories  \
# 4              Kohola Reef Restaurant                  BBQ Joint
# 5               Las Brisas Restaurant                       Food
# 0     Via Brasil Brazilian Restaurant       Brazilian Restaurant
# 12              Thunder Falls Terrace                  BBQ Joint
# 9                    Oshio Korean BBQ          Korean Restaurant
# 15                             Mythos           Greek Restaurant
# 11              Tavistock Restaurants                   Building
# 3           Nile Ethiopian Restaurant       Ethiopian Restaurant
# 1            World's Magic Restaurant  Middle Eastern Restaurant
# 13  Circus McGurkus Cafe Stoo-pendous                      Diner
# 10                Chili's Grill & Bar         Tex-Mex Restaurant
# 2            Punjab Indian Restaurant    North Indian Restaurant
# 14               Vivo Italian Kitchen         Italian Restaurant
# 6            Orlando Asian Restaurant                       Food
# 8    Bob Marley: A Tribute To Freedom       Caribbean Restaurant
# 7              Maza Indian Restaurant          Indian Restaurant
#
#                              address        lat        lng  \
# 4                       Wave Village  28.462716 -81.472433
# 5              6233 International Dr  28.462166 -81.467087
# 0              6315 International Dr  28.461344 -81.467443
# 12                     Jurassic Park  28.469765 -81.473314
# 9                  6800 Visitors Cir  28.463251 -81.465498
# 15                The Lost Continent  28.472640 -81.471439
# 11               7680 Universal Blvd  28.461786 -81.463047
# 3              7048 International Dr  28.457024 -81.472172
# 1              7044 International Dr  28.456947 -81.472190
# 13                     Seuss Landing  28.473163 -81.469803
# 10          7021 International Drive  28.456333 -81.470428
# 2   5489 W Irlo Bronson Memorial Hwy  28.455846 -81.470344
# 14               6000 Universal Blvd  28.473063 -81.465647
# 6                    6532 Carrier Dr  28.455679 -81.470238
# 8                6000 Universal Blvd  28.472875 -81.465123
# 7              7342 International Dr  28.455137 -81.471434
#
#                                        labeledLatLngs  distance postalCode  \
# 4   [{'label': 'display', 'lat': 28.46271588727033...       289      32819
# 5   [{'label': 'entrance', 'lat': 28.461708, 'lng'...       515      32819
# 0   [{'label': 'display', 'lat': 28.46134391842936...       554      32819
# 12  [{'label': 'display', 'lat': 28.46976489750437...       561      32819
# 9   [{'label': 'display', 'lat': 28.46325100820970...       592      32819
# 15  [{'label': 'display', 'lat': 28.47264026289861...       842      32819
# 11  [{'label': 'display', 'lat': 28.46178633363962...       876      32819
# 3   [{'label': 'display', 'lat': 28.45702369477081...       901      32819
# 1   [{'label': 'display', 'lat': 28.45694718721659...       910      32819
# 13  [{'label': 'display', 'lat': 28.47316347107087...       910      32819
# 10  [{'label': 'display', 'lat': 28.4563328, 'lng'...       976      32819
# 2   [{'label': 'display', 'lat': 28.455846, 'lng':...      1030      34746
# 14  [{'label': 'display', 'lat': 28.47306265781803...      1041      32819
# 6   [{'label': 'display', 'lat': 28.45567893981933...      1050      32819
# 8   [{'label': 'display', 'lat': 28.47287499588204...      1051      32819
# 7   [{'label': 'display', 'lat': 28.45513739041267...      1106      32819
#
#     cc       city state        country  \
# 4   US    Orlando    FL  United States
# 5   US    Orlando    FL  United States
# 0   US    Orlando    FL  United States
# 12  US    Orlando    FL  United States
# 9   US    Orlando    FL  United States
# 15  US    Orlando    FL  United States
# 11  US    Orlando    FL  United States
# 3   US    Orlando    FL  United States
# 1   US    Orlando    FL  United States
# 13  US    Orlando    FL  United States
# 10  US    Orlando    FL  United States
# 2   US  Kissimmee    FL  United States
# 14  US    Orlando    FL  United States
# 6   US    Orlando    FL  United States
# 8   US    Orlando    FL  United States
# 7   US    Orlando    FL  United States
#
#                                      formattedAddress  \
# 4   [Wave Village (Universal's Volcano Bay), Orlan...
# 5   [6233 International Dr, Orlando, FL 32819, Uni...
# 0   [6315 International Dr, Orlando, FL 32819, Uni...
# 12  [Jurassic Park (Islands of Adventure), Orlando...
# 9   [6800 Visitors Cir, Orlando, FL 32819, United ...
# 15  [The Lost Continent (at Islands of Adventure),...
# 11  [7680 Universal Blvd, Orlando, FL 32819, Unite...
# 3   [7048 International Dr, Orlando, FL 32819, Uni...
# 1   [7044 International Dr, Orlando, FL 32819, Uni...
# 13  [Seuss Landing (at Islands of Adventure), Orla...
# 10  [7021 International Drive, Orlando, FL 32819, ...
# 2   [5489 W Irlo Bronson Memorial Hwy, Kissimmee, ...
# 14  [6000 Universal Blvd (at Universal CityWalk), ...
# 6   [6532 Carrier Dr, Orlando, FL 32819, United St...
# 8   [6000 Universal Blvd (at Universal Citywalk), ...
# 7   [7342 International Dr (Slingshot), Orlando, F...
#
#                 crossStreet                        id
# 4   Universal's Volcano Bay  5900dbfb67e5f22787d2e7be
# 5                       NaN  4f327fbb19836c91c7ddbf07
# 0                       NaN  58b1ada219b1ad54934d5229
# 12     Islands of Adventure  4b5c7d95f964a520783229e3
# 9                       NaN  54e02fbb498e4bfeb5320730
# 15  at Islands of Adventure  4b50c562f964a520b83127e3
# 11                      NaN  4e147ff1ae60fe00dfdf9326
# 3                       NaN  4b5a50a6f964a52082bc28e3
# 1                       NaN  5888f80d55d622104fdc11e8
# 13  at Islands of Adventure  4baa623af964a52008653ae3
# 10                      NaN  4b638a95f964a52013822ae3
# 2                       NaN  58cc7dd1c9602779d134d0ad
# 14    at Universal CityWalk  539ce2dd498e40a9f6829815
# 6                       NaN  4f329ec819836c91c7e97ef3
# 8     at Universal Citywalk  4beded76e24d20a144417214
# 7                 Slingshot  5ca7c147fd16bb00390a2773

# %%
#3 Loews Portofino Bay Hotel at Universal Orlando
latitude = 28.480846
longitude = -81.460843
search_query = 'restaurant'
radius = 1000
print(search_query + ' .... OK!')
# Out:
# restaurant .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
results_3 = requests.get(url).json()
venues_3 = results_3['response']['venues']

# tranform venues into a dataframe
restaurant3 = json_normalize(venues_3)
restaurant3.sort_values(by=['location.distance'], ascending = True, inplace=True)
restaurant3.head()
# Out:
# C:\Users\xueya\anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                          id                        name  \
# 1  4d101b9f38bb6ea8c1a8c2aa     Mama Della's Ristorante
# 3  4bd38fa3462cb7133ccede07                BiCE Orlando
# 2  4f3226c419836c91c7bb38c5     Sawadee Thai Restaurant
# 8  4b058697f964a520256722e3            The Palm Orlando
# 0  4bfe9064f7c82d7f0dc18f04  Louie's Italian Restaurant
#
#                                           categories    referralId  hasPerk  \
# 1  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1593502223    False
# 3  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1593502223    False
# 2  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...  v-1593502223    False
# 8  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...  v-1593502223    False
# 0  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1593502223    False
#
#       location.address          location.crossStreet  location.lat  \
# 1  5601 Universal Blvd  in Loews Portofino Bay Hotel     28.480721
# 3  5601 Universal Blvd                           NaN     28.480604
# 2    5320 S Kirkman Rd                           NaN     28.484976
# 8  5800 Universal Blvd                           NaN     28.477117
# 0             New York     Universal Studios Florida     28.477348
#
#    location.lng                            location.labeledLatLngs  ...  \
# 1    -81.460840  [{'label': 'display', 'lat': 28.48072131753682...  ...
# 3    -81.461364  [{'label': 'display', 'lat': 28.48060427313225...  ...
# 2    -81.459641  [{'label': 'display', 'lat': 28.48497581481933...  ...
# 8    -81.464620  [{'label': 'display', 'lat': 28.47711656455560...  ...
# 0    -81.469196  [{'label': 'display', 'lat': 28.47734786754995...  ...
#
#    location.state location.country  \
# 1              FL    United States
# 3              FL    United States
# 2              FL    United States
# 8              FL    United States
# 0              FL    United States
#
#                            location.formattedAddress delivery.id  \
# 1  [5601 Universal Blvd (in Loews Portofino Bay H...         NaN
# 3  [5601 Universal Blvd, Orlando, FL 32819, Unite...     1589356
# 2  [5320 S Kirkman Rd, Orlando, FL 32819, United ...         NaN
# 8  [5800 Universal Blvd, Orlando, FL 32819, Unite...     1649243
# 0  [New York (Universal Studios Florida), Orlando...         NaN
#
#                                         delivery.url delivery.provider.name  \
# 1                                                NaN                    NaN
# 3  https://www.grubhub.com/restaurant/bice-orland...                grubhub
# 2                                                NaN                    NaN
# 8  https://www.grubhub.com/restaurant/the-palm-or...                grubhub
# 0                                                NaN                    NaN
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 1                                       NaN                          NaN
# 3  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 2                                       NaN                          NaN
# 8  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 0                                       NaN                          NaN
#
#                delivery.provider.icon.name venuePage.id
# 1                                      NaN          NaN
# 3  /delivery_provider_grubhub_20180129.png    347943049
# 2                                      NaN          NaN
# 8  /delivery_provider_grubhub_20180129.png          NaN
# 0                                      NaN          NaN
#
# [5 rows x 24 columns]

# %%
filtered_columns3 = ['name', 'categories'] + [col for col in restaurant3.columns if col.startswith('location.')] + ['id']
restaurant3_filtered = restaurant3.loc[:, filtered_columns3]
# filter the category for each row
restaurant3_filtered['categories'] = restaurant3_filtered.apply(get_category_type, axis=1)
# clean column names by keeping only last term
restaurant3_filtered.columns = [column.split('.')[-1] for column in restaurant3_filtered.columns]
restaurant3_filtered.shape
# Out:
# (11, 15)

# %%
restaurant3_filtered
# Out:
#                                  name            categories  \
# 1             Mama Della's Ristorante    Italian Restaurant
# 3                        BiCE Orlando    Italian Restaurant
# 2             Sawadee Thai Restaurant       Thai Restaurant
# 8                    The Palm Orlando            Steakhouse
# 0          Louie's Italian Restaurant    Italian Restaurant
# 6    Bob Marley: A Tribute To Freedom  Caribbean Restaurant
# 9                Vivo Italian Kitchen    Italian Restaurant
# 4                    Tabla Restaurant     Indian Restaurant
# 5   Golden Buffet Chinesse Restaurant                  Food
# 10                  Vinito Ristorante    Italian Restaurant
# 7           Kim Wu Chinese Restaurant    Chinese Restaurant
#
#                    address                               crossStreet  \
# 1      5601 Universal Blvd              in Loews Portofino Bay Hotel
# 3      5601 Universal Blvd                                       NaN
# 2        5320 S Kirkman Rd                                       NaN
# 8      5800 Universal Blvd                                       NaN
# 0                 New York                 Universal Studios Florida
# 6      6000 Universal Blvd                     at Universal Citywalk
# 9      6000 Universal Blvd                     at Universal CityWalk
# 4   5847 Grand National Dr                              Kirkman Road
# 5    4949 International Dr                                       NaN
# 10   4971 International Dr  at Orlando International Premium Outlets
# 7        4904 S Kirkman Rd                              at Conroy Rd
#
#           lat        lng                                     labeledLatLngs  \
# 1   28.480721 -81.460840  [{'label': 'display', 'lat': 28.48072131753682...
# 3   28.480604 -81.461364  [{'label': 'display', 'lat': 28.48060427313225...
# 2   28.484976 -81.459641  [{'label': 'display', 'lat': 28.48497581481933...
# 8   28.477117 -81.464620  [{'label': 'display', 'lat': 28.47711656455560...
# 0   28.477348 -81.469196  [{'label': 'display', 'lat': 28.47734786754995...
# 6   28.472875 -81.465123  [{'label': 'display', 'lat': 28.47287499588204...
# 9   28.473063 -81.465647  [{'label': 'display', 'lat': 28.47306265781803...
# 4   28.472176 -81.455630  [{'label': 'display', 'lat': 28.4721764, 'lng'...
# 5   28.473557 -81.452805  [{'label': 'display', 'lat': 28.47355651855468...
# 10  28.474929 -81.450940  [{'label': 'display', 'lat': 28.47492895231341...
# 7   28.491337 -81.459709  [{'label': 'display', 'lat': 28.49133651608589...
#
#     distance postalCode  cc     city state        country  \
# 1         13      32819  US  Orlando    FL  United States
# 3         57      32819  US  Orlando    FL  United States
# 2        474      32819  US  Orlando    FL  United States
# 8        555      32819  US  Orlando    FL  United States
# 0        905      32819  US  Orlando    FL  United States
# 6        981      32819  US  Orlando    FL  United States
# 9        985      32819  US  Orlando    FL  United States
# 4       1091      32819  US  Orlando    FL  United States
# 5       1130      32819  US  Orlando    FL  United States
# 10      1171      32819  US  Orlando    FL  United States
# 7       1173      32811  US  Orlando    FL  United States
#
#                                      formattedAddress  \
# 1   [5601 Universal Blvd (in Loews Portofino Bay H...
# 3   [5601 Universal Blvd, Orlando, FL 32819, Unite...
# 2   [5320 S Kirkman Rd, Orlando, FL 32819, United ...
# 8   [5800 Universal Blvd, Orlando, FL 32819, Unite...
# 0   [New York (Universal Studios Florida), Orlando...
# 6   [6000 Universal Blvd (at Universal Citywalk), ...
# 9   [6000 Universal Blvd (at Universal CityWalk), ...
# 4   [5847 Grand National Dr (Kirkman Road), Orland...
# 5   [4949 International Dr, Orlando, FL 32819, Uni...
# 10  [4971 International Dr (at Orlando Internation...
# 7   [4904 S Kirkman Rd (at Conroy Rd), Orlando, FL...
#
#                           id
# 1   4d101b9f38bb6ea8c1a8c2aa
# 3   4bd38fa3462cb7133ccede07
# 2   4f3226c419836c91c7bb38c5
# 8   4b058697f964a520256722e3
# 0   4bfe9064f7c82d7f0dc18f04
# 6   4beded76e24d20a144417214
# 9   539ce2dd498e40a9f6829815
# 4   4b058699f964a5206a6722e3
# 5   4f3291af19836c91c7e4952a
# 10  4b8c01fcf964a5200ab832e3
# 7   4b69b94cf964a5201cb02be3

# %% [markdown]
# # create a plot of distance-rating

# %%
drate = {'Name':["Loews Portofino Bay Hotel at Universal Orlando",
"Loews Royal Pacific Resort",
"Universal's Aventura Hotel",
"Club 7 at the Hard Rock Hotel",
"Holiday Inn & Suites Across From Universal Orlando",
"Best Western Orlando Gateway Hotel",
"Orlando Continental Plaza Hotel"
],
        'Rating':[9.2, 8.8 ,8.1, 6.9, 6.9, 6.6, 5.2],
        'Distance':[1423, 511, 757, 891 ,1421, 1709, 1107]}

# %%
rate_dis = pd.DataFrame(drate)
rate_dis
# Out:
#                                                 Name  Rating  Distance
# 0     Loews Portofino Bay Hotel at Universal Orlando     9.2      1423
# 1                         Loews Royal Pacific Resort     8.8       511
# 2                         Universal's Aventura Hotel     8.1       757
# 3                      Club 7 at the Hard Rock Hotel     6.9       891
# 4  Holiday Inn & Suites Across From Universal Orl...     6.9      1421
# 5                 Best Western Orlando Gateway Hotel     6.6      1709
# 6                    Orlando Continental Plaza Hotel     5.2      1107

# %%
rate_dis.plot(x ='Distance', y='Rating', kind = 'scatter')

# %% [markdown]
# ## Regression

# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
import pandas as pd 

from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot

series = pd.read_csv (r'D:\Texas A&M University\Summer 2020\Python\IBM Data Science Professional\9.Capstone\US-covid.csv')
print(series)
# Out:
#     date_start                   country  confirmed_cases  deaths  recovered  \
# 0    1/22/2020  United States of America                1       0          0
# 1    1/23/2020  United States of America                1       0          0
# 2    1/24/2020  United States of America                2       0          0
# 3    1/25/2020  United States of America                2       0          0
# 4    1/26/2020  United States of America                5       0          0
# ..         ...                       ...              ...     ...        ...
# 129  5/30/2020  United States of America          1770165  103776     416461
# 130  5/31/2020  United States of America          1790172  104381     444758
# 131   6/1/2020  United States of America          1811020  105149     458231
# 132   6/2/2020  United States of America          1831821  106180     463868
# 133   6/3/2020  United States of America          1851520  107175     479258
#
#       active  log-active
# 0          1    0.000000
# 1          1    0.000000
# 2          2    0.693147
# 3          2    0.693147
# 4          5    1.609438
# ..       ...         ...
# 129  1249928   14.038597
# 130  1241033   14.031455
# 131  1247640   14.036764
# 132  1261773   14.048028
# 133  1265087   14.050651
#
# [134 rows x 7 columns]
# C:\Users\xueya\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#
# C:\Users\xueya\anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   import sys

# %%
series.head()
plt.xlabel('Date')
plt.ylabel('Active cases')
plt.plot(series['log-active'])

# %% [markdown]
# ## Import csv file

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
df = pd.read_csv(r'D:\Texas A&M University\Summer 2020\Python\IBM Data Science Professional\9.Capstone\US.csv', parse_dates = ['date_start'], index_col = ['date_start'])
df.head()
plt.xlabel('Date')
plt.ylabel('Log of active cases')
plt.plot(df['log_active'][0:133])

# %% [markdown]
# ### ADF test of log(active cases)

# %%
result = adfuller(df['log_active'])
print('ADF Statistic: {}'.format(result[0]))
print('p-value: {}'.format(result[1]))
print('Critical Values:')
for key, value in result[4].items():
    print('\t{}: {}'.format(key, value))
# Out:
# ADF Statistic: -1.645296370982438
# p-value: 0.4594946462270914
# Critical Values:
# 	1%: -3.4816817173418295
# 	5%: -2.8840418343195267
# 	10%: -2.578770059171598

# %% [markdown]
# ##### This log of active cases series is not stationary.

# %% [markdown]
# ### Calculate the first difference of log(active cases)

# %%
df_shift = df - df.shift()
df_shift.dropna(inplace=True)

# %%
df_shift.head()
# Out:
#             log_active  time
# date_start
# 2020-01-23    0.000000     1
# 2020-01-24    0.693147     2
# 2020-01-25    0.000000     3
# 2020-01-26    0.916291     4
# 2020-01-27    0.000000     5

# %% [markdown]
# #### ADF test of first differenced log(active cases)

# %%
result = adfuller(df_shift['log_active'])
print('ADF Statistic: {}'.format(result[0]))
print('p-value: {}'.format(result[1]))
print('Critical Values:')
for key, value in result[4].items():
    print('\t{}: {}'.format(key, value))
# Out:
# ADF Statistic: -4.192485632973042
# p-value: 0.000678466536687841
# Critical Values:
# 	1%: -3.4816817173418295
# 	5%: -2.8840418343195267
# 	10%: -2.578770059171598

# %% [markdown]
# ##### This first differenced log(active cases) series is stationary

# %% [markdown]
# ### ARIMA + Trend

# %%
t=range(1,134)
df_shift['time']=t
df_shift.head()
# Out:
#             log_active  time
# date_start
# 2020-01-23    0.000000     1
# 2020-01-24    0.693147     2
# 2020-01-25    0.000000     3
# 2020-01-26    0.916291     4
# 2020-01-27    0.000000     5

# %%
model2 = ARIMA(df_shift['log_active'], order=(2,0,1),exog=df_shift['time'])
model_fit2 = model2.fit()
print(model_fit2.summary())
plt.plot(df_shift['log_active'])
plt.plot(model_fit2.fittedvalues,color='red')
residuals2 = pd.DataFrame(model_fit2.resid)
residuals2.plot()
pyplot.show()
residuals2.plot(kind='kde')
pyplot.show()
print(residuals2.describe())
# Out:
# C:\Users\xueya\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:             log_active   No. Observations:                  133
# Model:                     ARMA(2, 1)   Log Likelihood                  41.984
# Method:                       css-mle   S.D. of innovations              0.176
# Date:                Wed, 01 Jul 2020   AIC                            -71.968
# Time:                        00:37:58   BIC                            -54.626
# Sample:                    01-23-2020   HQIC                           -64.921
#                          - 06-03-2020
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.2158      0.072      3.003      0.003       0.075       0.357
# time                -0.0016      0.001     -1.772      0.076      -0.003       0.000
# ar.L1.log_active     0.7034      0.127      5.532      0.000       0.454       0.953
# ar.L2.log_active     0.2011      0.095      2.115      0.034       0.015       0.387
# ma.L1.log_active    -0.7422      0.103     -7.239      0.000      -0.943      -0.541
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0851           +0.0000j            1.0851            0.0000
# AR.2           -4.5828           +0.0000j            4.5828            0.5000
# MA.1            1.3474           +0.0000j            1.3474            0.0000
# -----------------------------------------------------------------------------
#                 0
# count  133.000000
# mean    -0.001895
# std      0.177936
# min     -0.418063
# 25%     -0.044017
# 50%     -0.011795
# 75%      0.004954
# max      1.469446

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
fig = plot_acf(residuals2, 
               title="Autocorrelation on Residual Series")

# %%
start_index = '2020-06-04'
end_index = '2020-12-31'
newt=range(134,345)
forecast = model_fit2.predict(start=start_index, end=end_index,exog=newt)

# %%
forecast
# Out:
# 2020-06-04    0.000197
# 2020-06-05   -0.001049
# 2020-06-06   -0.002565
# 2020-06-07   -0.004035
# 2020-06-08   -0.005526
#                 ...
# 2020-12-27   -0.326478
# 2020-12-28   -0.328073
# 2020-12-29   -0.329668
# 2020-12-30   -0.331263
# 2020-12-31   -0.332858
# Freq: D, Length: 211, dtype: float64

# %%
path=r'D:\Texas A&M University\Summer 2020\Python\IBM Data Science Professional\9.Capstone'

# %%
fct = pd.DataFrame(forecast)
fct.to_csv(path+'\\fct.csv',sep=',',index=False)

# %% [markdown]
# # Plot the forecasting values of active cases

# %%
logfct = pd.read_csv(r'D:\Texas A&M University\Summer 2020\Python\IBM Data Science Professional\9.Capstone\log_active_fct.csv', parse_dates = ['date_start'], index_col = ['date_start'])
logfct.head()
plt.xlabel('Date')
plt.ylabel('Log of active cases')
plt.plot(logfct)

# %%
acfct = pd.read_csv(r'D:\Texas A&M University\Summer 2020\Python\IBM Data Science Professional\9.Capstone\Active_fct.csv', parse_dates = ['date_start'], index_col = ['date_start'])
acfct.tail(15)
# Out:
#             Active
# date_start
# 2020-10-05       8
# 2020-10-06       7
# 2020-10-07       6
# 2020-10-08       5
# 2020-10-09       4
# 2020-10-10       3
# 2020-10-11       3
# 2020-10-12       2
# 2020-10-13       2
# 2020-10-14       1
# 2020-10-15       1
# 2020-10-16       1
# 2020-10-17       1
# 2020-10-18       1
# 2020-10-19       0

# %%
plt.xlabel('Date')
plt.ylabel('Active Cases')
plt.plot(acfct)
